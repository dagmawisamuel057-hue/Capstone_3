# %%
import datetime

# %%
current_time = datetime.datetime.now()
print(current_time)
# Out:
# 2026-05-12 09:37:22.063798

# %%
today = datetime.date.today()
print(today)
# Out:
# 2026-05-12

# %%
now = datetime.datetime.now()
print(now.time())
# Out:
# 09:38:07.171594

# %%
birthday = datetime.date(1998, 12, 24)
print(birthday)
# Out:
# 1998-12-24

# %%
difference = today - birthday
print(difference)
# Out:
# 10001 days, 0:00:00

# %%
formatted = current_time.strftime("%B %d, %Y")
print(formatted)
# Out:
# May 12, 2026

# %%
formatted_time = current_time.strftime("%I:%M %p")
print(formatted_time)
# Out:
# 09:37 AM
