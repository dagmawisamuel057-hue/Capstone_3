# %% [markdown]
# # Sales Records Analysis
# ### Author: Dagmawi Mulugeta
# ### Exercise 2.E Using functions for analyzing data
#
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
    ('Laptop', 'East', 1200.00),
    ('Tablet', 'West', 425.00),
    ('Monitor', 'East', 680.00),
    ('Keyboard', 'South', 80.00),
    ('Laptop', 'West', 1300.00),
    ('Phone', 'West', 820.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
    return sum(amt for _, r, amt in data if r == region)

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))
# Out:
# 1880.0
# 2545.0
# 80.0

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, _ in data if r == region)

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))
# Out:
# 2
# 3
# 1

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    count = region_count(data, region)

    if count == 0:
        return 0

    return region_total(data, region) / count

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
print(region_average(sales_data, 'North'))
# Out:
# 940.0
# 848.3333333333334
# 80.0
# 0

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def filter_by_amount(data, minimum_amount):
    return [record for record in data if record[2] >= minimum_amount]

# %%
print(filter_by_amount(sales_data, 800))
# Out:
# [('Laptop', 'East', 1200.0), ('Laptop', 'West', 1300.0), ('Phone', 'West', 820.0)]

# %% [markdown]
# ## Lab 5. Top sale

# %%
def top_sale(data):
    return max(data, key=lambda record: record[2])

# %%
print(top_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)

# %% [markdown]
# ## Lab 6. Apply discount

# %%
def apply_discount(data, discount_pct):
    return list(map(lambda s: (s[0], s[1], s[2] * (1 - discount_pct)), data))

# %%
discounted_data = apply_discount(sales_data, 0.15)

print("Before discount:")
print(sales_data[:3])

print("\nAfter 15% discount:")
print(discounted_data[:3])
# Out:
# Before discount:
# [('Laptop', 'East', 1200.0), ('Tablet', 'West', 425.0), ('Monitor', 'East', 680.0)]
#
# After 15% discount:
# [('Laptop', 'East', 1020.0), ('Tablet', 'West', 361.25), ('Monitor', 'East', 578.0)]

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(r for _, r, _ in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# This function is useful because it lets us quickly identify all regions in a dataset without duplicates. In a larger analysis program, this pattern could help generate reports by region automatically instead of manually typing each region name.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_records = [record for record in data if record[1] == region]

    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)

    if count == 0:
        print(f"=== {region} Region ===")
        print("No records found.")
        return

    top = top_sale(region_records)

    print(f"=== {region} Region ===")
    print(f"Records: {count}")
    print(f"Total Sales: ${total:,.2f}")
    print(f"Average Sale: ${average:,.2f}")
    print(f"Top Sale: {top[0]} — ${top[2]:,.2f}")

# %%
region_summary(sales_data, 'East')
region_summary(sales_data, 'West')
region_summary(sales_data, 'South')
# Out:
# === East Region ===
# Records: 2
# Total Sales: $1,880.00
# Average Sale: $940.00
# Top Sale: Laptop — $1,200.00
# === West Region ===
# Records: 3
# Total Sales: $2,545.00
# Average Sale: $848.33
# Top Sale: Laptop — $1,300.00
# === South Region ===
# Records: 1
# Total Sales: $80.00
# Average Sale: $80.00
# Top Sale: Keyboard — $80.00

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data, region)
    print()
# Out:
# === East Region ===
# Records: 2
# Total Sales: $1,880.00
# Average Sale: $940.00
# Top Sale: Laptop — $1,200.00
#
# === South Region ===
# Records: 1
# Total Sales: $80.00
# Average Sale: $80.00
# Top Sale: Keyboard — $80.00
#
# === West Region ===
# Records: 3
# Total Sales: $2,545.00
# Average Sale: $848.33
# Top Sale: Laptop — $1,300.00

# %% [markdown]
# ## Summary
#
# In this exercise, I learned how to use functions to analyze a sales dataset. I practiced calculating totals, counts, averages, filtering records, applying discounts, finding unique regions, and generating a summary report. This helped me understand how functions can make data analysis cleaner, reusable, and easier to organize.
